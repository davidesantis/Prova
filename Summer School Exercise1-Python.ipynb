# %% [markdown]
# # Earth System Data Lab Exercise - EO Summer School 2018
#
# # Exercise 1: Introduction to Earth System Data Lab and its API to access the cube data
#
# ## The Data Analytics Toolkit for Python
#
# This notebook is describes how to use access the Eart System Data Cube (ESDC) using the Python Data Analytics Toolkit (DAT). It is meant as a starting point for the exploaration and analysis of the ESDC. The Python DAT draws heavily on [xarray](http://xarray.pydata.org/en/stable/), a "pandas-like and pandas-compatible toolkit for analytics on multi-dimensional arrays". Xarray implements the common data model of Netcdf in memory and nicely conserves the strucutre and all metainformation of the data in the ESDC. Thus, the full power of xarray and dask (for out-of-core computation) is immediatley available ot work with ESDC.
#
# In the following, typical steps a first-time user may take to explore the ESDC and common analytical procedures and visualisations are introduced. Note, however, that this example is b yno means exhaustive - the DAT is full ycompatible with the entire Python ecosystem and therefore offers almost unlimited approahces to specific analyitical needs.

# %%
import xarray as xr

# %% [markdown]
# ### Open the low-resolution data cube
#
# There are two ways to achieve this. Either use native ESDL Data Access API:

# %%
#from esdl import Cube

#cube = Cube.open("/home/jovyan/work/datacube/esdc-8d-0.25deg-1x720x1440-1.0.1_1")
#ESDC = cube.data.dataset()    # this converts the cube object to xarray Dataset. It may take a while...

# %% [markdown]
# ... or open the zarr version of the cube using xarray open_zarr function (this is only applicable to zarr cube (i.e. one with "zarr" suffix at the cube name)):

# %%
ESDC = xr.open_zarr("/home/jovyan/work/datacube/esdc-8d-0.25deg-1x720x1440-1.0.1_1_zarr")

# %% [markdown]
# **NOTE:** Zarr cube is still at experimental phase. It is usable but not all cubes have their equivalent zarr cubes
#
# References:<br>
# zarr: https://zarr.readthedocs.io/en/stable/<br>
# xarray open dataset API: http://xarray.pydata.org/en/stable/api.html#dataset-methods

# %%
ESDC.precipitation
# Out:
# <xarray.DataArray 'precipitation' (time: 506, lat: 720, lon: 1440)>
# dask.array<shape=(506, 720, 1440), dtype=float32, chunksize=(1, 720, 1440)>
# Coordinates:
#   * lat      (lat) float32 89.875 89.625 89.375 89.125 88.875 88.625 88.375 ...
#   * lon      (lon) float32 -179.875 -179.625 -179.375 -179.125 -178.875 ...
#   * time     (time) datetime64[ns] 2001-01-05 2001-01-13 2001-01-21 ...
# Attributes:
#     comment:        Precipitation based on the GPCP dataset.
#     project_name:   GPCP
#     references:     Adler, Robert F., et al. "The version-2 global precipitat...
#     source_name:    Precip
#     standard_name:  precipitation_flux
#     units:          mm/day
#     url:            http://precip.gsfc.nasa.gov/

# %% [markdown]
# ### The array of values can be also accessed directly

# %%
ESDC['lon'].values
# Out:
# array([-179.875, -179.625, -179.375, ...,  179.375,  179.625,  179.875], dtype=float32)

# %% [markdown]
# ###  xarray offers rich set of built-in convenience functions
# see the [API reference](http://xarray.pydata.org/en/stable/api.html) for full reference!
# ### Mean over all dimensions

# %%
all_mean = ESDC.mean(skipna=True).compute()
all_mean
# Out:
# <xarray.Dataset>
# Dimensions:                            ()
# Data variables:
#     aerosol_optical_thickness_1610     float32 0.106666
#     aerosol_optical_thickness_550      float32 0.173698
#     aerosol_optical_thickness_555      float32 0.172338
#     aerosol_optical_thickness_659      float32 0.148715
#     aerosol_optical_thickness_865      float32 0.124077
#     air_temperature_2m                 float32 278.716
#     bare_soil_evaporation              float32 0.0536708
#     black_sky_albedo                   float32 0.421412
#     burnt_area                         float32 28.3154
#     c_emissions                        float32 0.24708
#     country_mask                       float64 297.4
#     evaporation                        float32 0.819095
#     evaporative_stress                 float32 0.806238
#     fractional_snow_cover              float32 25.7361
#     gross_primary_productivity         float32 2.27052
#     interception_loss                  float32 0.0793832
#     land_surface_temperature           float32 277.27
#     latent_energy                      float32 3.48564
#     net_ecosystem_exchange             float32 -0.345845
#     open_water_evaporation             float32 0.100386
#     ozone                              float32 296.557
#     potential_evaporation              float32 1.18561
#     precipitation                      float32 1.57122
#     root_moisture                      float32 0.192694
#     sensible_heat                      float32 2.64396
#     snow_sublimation                   float32 0.0193239
#     snow_water_equivalent              float32 8.66193
#     soil_moisture                      float32 0.212216
#     srex_mask                          float32 17.6274
#     surface_moisture                   float32 0.206969
#     terrestrial_ecosystem_respiration  float32 1.92714
#     transpiration                      float32 0.565893
#     water_mask                         float32 1.64665
#     water_vapour                       float32 22.1181
#     white_sky_albedo                   float32 0.397043

# %% [markdown]
# ### Mean over time and latitude, result is a dataset again

# %%
precip_avg = ESDC['precipitation'].mean(dim = ["time","lat"], skipna=True).compute()
precip_avg
# Out:
# <xarray.DataArray 'precipitation' (lon: 1440)>
# array([ 1.07089 ,  1.07089 ,  0.952765, ...,  1.645363,  1.262889,  1.262889], dtype=float32)
# Coordinates:
#   * lon      (lon) float32 -179.875 -179.625 -179.375 -179.125 -178.875 ...

# %% [markdown]
# ###  Simple plotting with xarrays implementation of matplotlib
# #### import additional libraries

# %%
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sn
# %matplotlib inline

# %% [markdown]
# ### Select 2d image (lat/lon) given a time as integer index

# %%
precip2d = ESDC.precipitation.isel(time=123)
precip2d
# Out:
# <xarray.DataArray 'precipitation' (lat: 720, lon: 1440)>
# dask.array<shape=(720, 1440), dtype=float32, chunksize=(720, 1440)>
# Coordinates:
#   * lat      (lat) float32 89.875 89.625 89.375 89.125 88.875 88.625 88.375 ...
#   * lon      (lon) float32 -179.875 -179.625 -179.375 -179.125 -178.875 ...
#     time     datetime64[ns] 2003-09-10
# Attributes:
#     comment:        Precipitation based on the GPCP dataset.
#     project_name:   GPCP
#     references:     Adler, Robert F., et al. "The version-2 global precipitat...
#     source_name:    Precip
#     standard_name:  precipitation_flux
#     units:          mm/day
#     url:            http://precip.gsfc.nasa.gov/

# %% [markdown]
# ### or given a specific date

# %%
precip2d = ESDC['precipitation'].sel(time='2007-04-19T12:00:00', method = 'nearest')
precip2d
# Out:
# <xarray.DataArray 'precipitation' (lat: 720, lon: 1440)>
# dask.array<shape=(720, 1440), dtype=float32, chunksize=(720, 1440)>
# Coordinates:
#   * lat      (lat) float32 89.875 89.625 89.375 89.125 88.875 88.625 88.375 ...
#   * lon      (lon) float32 -179.875 -179.625 -179.375 -179.125 -178.875 ...
#     time     datetime64[ns] 2007-04-19
# Attributes:
#     comment:        Precipitation based on the GPCP dataset.
#     project_name:   GPCP
#     references:     Adler, Robert F., et al. "The version-2 global precipitat...
#     source_name:    Precip
#     standard_name:  precipitation_flux
#     units:          mm/day
#     url:            http://precip.gsfc.nasa.gov/

# %%
precip1d = ESDC['precipitation'].sel(lon = 12.67,lat = 41.83, method = 'nearest')
precip1d
# Out:
# <xarray.DataArray 'precipitation' (time: 506)>
# dask.array<shape=(506,), dtype=float32, chunksize=(1,)>
# Coordinates:
#     lat      float32 41.875
#     lon      float32 12.625
#   * time     (time) datetime64[ns] 2001-01-05 2001-01-13 2001-01-21 ...
# Attributes:
#     comment:        Precipitation based on the GPCP dataset.
#     project_name:   GPCP
#     references:     Adler, Robert F., et al. "The version-2 global precipitat...
#     source_name:    Precip
#     standard_name:  precipitation_flux
#     units:          mm/day
#     url:            http://precip.gsfc.nasa.gov/

# %% [markdown]
# #### Plot 2d image with matplotlib

# %%
precip2d.plot.pcolormesh(vmax = 5, figsize=(18,9))

# %% [markdown]
# #### Time-series at a given location (here ESRIN), and histogram lf values

# %%
fig, ax = plt.subplots(figsize = [14,5], ncols=2)

precip1d.plot(ax = ax[0], color ='red', marker ='.')
ax[0].set_title("Precipitation at ESRIN")
precip1d.plot.hist(ax = ax[1], color ='blue')
ax[1].set_xlabel("precipitation")
plt.tight_layout()

# %% [markdown]
# ### Make use of the known and stable strucutre of all data in the ESDC and create high-level methods for visualization

# %%
from mpl_toolkits.basemap import Basemap
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Try to update this map_plot function to display more inofrmation on the plot

# %% [markdown]
# For example, you can configure the following:
# * set a title
# * set a colourbar
# * adjust the range to be displayed
# * add longitude and latitude lines
#
# Basemap: http://basemaptutorial.readthedocs.io/en/latest/index.html<br>
# Matplotlib Imshow(): https://matplotlib.org/api/_as_gen/matplotlib.pyplot.imshow.html

# %%
def map_plot(ds, var=None, time = 0, title_str='No title', **kwargs):
    ''' 
    Expects a data set and a variable name to plot
    
    '''
    if isinstance(time,int):
        res = ds[var].isel(time=time)
    elif time is None:
        res = ds[var]
        time = None
    else: 
        try: 
            res = ds[var].sel(time=time,method='nearest')
        except: 
            print("Wrong date format, should be YYYY-MM-DD")
            raise    
   
    lons, lats = np.meshgrid(np.array(res.lon),np.array(res.lat))
    ma_res = np.ma.array(res, mask =np.isnan(res))
    
    fig = plt.figure()
    m = Basemap(projection='kav7',lon_0=0,resolution=None)
    m.drawmapboundary(fill_color='0.3')
    im = m.pcolormesh(lons,lats,ma_res,shading='flat',latlon=True)
    ####################################
    # add your own configurations here #
    ####################################

    # write to disk if specified 
    if "plot_me" in kwargs:
        if kwargs["plot_me"] == True:
            plt.savefig(title_str[0:15] + '.png',dpi = 600)
            
    fig.set_size_inches(8,12)
    return fig ,ax, m

# %%
fig, ax, m = map_plot(ESDC,'evaporation','2006-03-01T12:00:00',vmax = 6.)

# %% [markdown]
# #### Subsetting geographical sub-region. Note that the slice of the latitude dimension has to be in reverse order.

# %%
Europe = ESDC.sel(lat = slice(50.,40.), lon = slice(-10.,35.))
Europe.mean(dim='time',skipna=True).soil_moisture.plot(figsize=(18,9))

# %% [markdown]
# ### Try selecting different region and different variable. Plot the result

# %%
# write your code here

# %% [markdown]
# #### Seasonal averages

# %%
Air_temp_monthly = Europe.air_temperature_2m.groupby('time.month').mean(dim='time') - 273.15

# %%
Air_temp_monthly.plot.imshow(x='lon',y='lat',col='month',col_wrap=3)

# %% [markdown]
# #### Zscores

# %%
Europe_zscore = (Europe-Europe.mean(dim='time'))/Europe.std(dim='time')

# %%
ESRIN_zscore = Europe_zscore.sel(lon = 12.67,lat = 41.83, method = 'nearest')
ESRIN_zscore.precipitation.plot(figsize=(18,9))

# %% [markdown]
# #### Using apply() to apply any arbitrary function to all variables in the dataset

# %%
Europe.apply(np.nanmax)
# Out:
# <xarray.Dataset>
# Dimensions:                            ()
# Data variables:
#     aerosol_optical_thickness_1610     float32 0.795612
#     aerosol_optical_thickness_550      float32 1.04091
#     aerosol_optical_thickness_555      float32 1.03522
#     aerosol_optical_thickness_659      float32 0.936246
#     aerosol_optical_thickness_865      float32 0.841456
#     air_temperature_2m                 float32 305.602
#     bare_soil_evaporation              float32 1.21136
#     black_sky_albedo                   float32 0.945793
#     burnt_area                         float32 17791.9
#     c_emissions                        float32 413.24
#     country_mask                       float64 807.0
#     evaporation                        float32 7.18561
#     evaporative_stress                 float32 1.0
#     fractional_snow_cover              float32 100.0
#     gross_primary_productivity         float32 12.5866
#     interception_loss                  float32 3.46082
#     land_surface_temperature           float32 327.462
#     latent_energy                      float32 10.637
#     net_ecosystem_exchange             float32 1.63208
#     open_water_evaporation             float32 7.18561
#     ozone                              float32 425.37
#     potential_evaporation              float32 7.20066
#     precipitation                      float32 37.7744
#     root_moisture                      float32 0.572554
#     sensible_heat                      float32 10.6864
#     snow_sublimation                   float32 3.95896
#     snow_water_equivalent              float32 369.742
#     soil_moisture                      float32 0.468
#     srex_mask                          float32 19.0
#     surface_moisture                   float32 0.575067
#     terrestrial_ecosystem_respiration  float32 5.95045
#     transpiration                      float32 5.75846
#     water_mask                         float32 2.0
#     water_vapour                       float32 61.3284
#     white_sky_albedo                   float32 0.823121

# %% [markdown]
# ### Define own function for anomaly detection.

# %%
def above_Nsigma(x,Nsigma):
    return xr.ufuncs.fabs(x)>Nsigma

# %%
res = Europe_zscore.apply(above_Nsigma,Nsigma = 2)

# %%
fig2, ax2 = plt.subplots(figsize = [12,5], ncols=2)

res["precipitation"].sum(dim="time").plot(ax = ax2[0])
ax2[0].set_title("No of obs above or below 2 sigma")

res["evaporation"].sum(dim="time").plot(ax = ax2[1])
ax2[1].set_title("No of obs above or below 2 sigma")

plt.tight_layout()

# %%
df = Europe_zscore.to_dataframe()
df.boxplot(column=["precipitation","evaporation","soil_moisture","ozone"])

# %%
df
# Out:
#                                 lat_bnds  lon_bnds  time_bnds  \
# bnds lat    lon     time
# 0    69.875 -19.875 2001-01-05     69.75     -20.0 2001-01-01
#                     2001-01-13     69.75     -20.0 2001-01-09
#                     2001-01-21     69.75     -20.0 2001-01-17
#                     2001-01-29     69.75     -20.0 2001-01-25
#                     2001-02-06     69.75     -20.0 2001-02-02
#                     2001-02-14     69.75     -20.0 2001-02-10
#                     2001-02-22     69.75     -20.0 2001-02-18
#                     2001-03-02     69.75     -20.0 2001-02-26
#                     2001-03-10     69.75     -20.0 2001-03-06
#                     2001-03-18     69.75     -20.0 2001-03-14
#                     2001-03-26     69.75     -20.0 2001-03-22
#                     2001-04-03     69.75     -20.0 2001-03-30
#                     2001-04-19           -1.375401                    NaN
#                     2001-04-27           -0.484628                    NaN
#                     2001-05-05            0.266797                    NaN
#                     2001-05-13            0.195198                    NaN
#                     2001-05-21            0.071640                    NaN
#                     2001-05-29            0.633740                    NaN
#                     2001-06-06            0.619569                    NaN
#                     2001-06-14            0.571666                    NaN
#                     2001-06-22            0.952399                    NaN
#                     2001-06-30            0.980039                    NaN
#                     2001-07-08            1.150934                    NaN
#                     2001-07-16            1.207940                    NaN
#                     2001-07-24            1.189423                    NaN
#                     2001-08-01            1.409448                    NaN
#                     2001-08-09            1.306234                    NaN
#                     2001-08-17            1.375645                    NaN
#                     2001-08-25            1.445189                    NaN
# ...                                            ...                    ...
# 1    30.125  34.875 2011-05-13           -0.089789              -0.336919
#                     2011-05-21            0.470664              -0.439227
#                     2011-05-29            0.814392              -0.523041
#                     2011-06-06            0.720842              -0.561272
#                     2011-06-14            0.835688              -0.577648
#                     2011-06-22            0.850770              -0.584612
#                     2011-06-30            0.818354              -0.587318
#                     2011-07-08            1.264047              -0.588428
#                     2011-07-16            1.263987              -0.588891
#                     2011-07-24            1.519655              -0.589077
#                     2011-08-01            1.518921              -0.589158
#                     2011-08-09            1.170854              -0.589194
#                     2011-08-17            1.036975              -0.589209
#                     2011-08-25            1.205116              -0.589216
#                     2011-09-02            0.850187              -0.589218
#                     2011-09-10            1.015779              -0.589218
#                     2011-09-18            0.949755              -0.589219
#                     2011-09-26            0.741616              -0.504411
#                     2011-10-04            0.465743              -0.508449
#                     2011-10-12            0.602583              -0.545381
#                     2011-10-20            0.141300              -0.563294
#                     2011-10-28           -0.257795              -0.572810
#                     2011-11-05           -0.627438              -0.578985
#                     2011-11-13           -0.650333              -0.582865
#                     2011-11-21           -1.139358              -0.392633
#                     2011-11-29           -1.416754              -0.410008
#                     2011-12-07           -1.358431              -0.460834
#                     2011-12-15           -1.416533              -0.450610
#                     2011-12-23           -1.112848              -0.451951
#                     2011-12-31           -1.515467              -0.408159
#
#                                       ...         snow_sublimation  \
# bnds lat    lon     time              ...
# 0    69.875 -19.875 2001-01-05        ...                      NaN
#                     2001-01-13        ...                      NaN
#                     2001-01-21        ...                      NaN
#                     2001-01-29        ...                      NaN
#                     2001-02-06        ...                      NaN
#                     2001-02-14        ...                      NaN
#                     2001-02-22        ...                      NaN
#                     2001-03-02        ...                      NaN
#                     2001-03-10        ...                      NaN
#                     2001-03-18        ...                      NaN
#                     2001-03-26        ...                      NaN
#                     2001-04-03        ...                      NaN
#                     2001-04-11        ...                      NaN
#                     2001-04-19        ...                      NaN
#                     2001-04-27        ...                      NaN
#                     2001-05-05        ...                      NaN
#                     2001-05-13        ...                      NaN
#                     2001-05-21        ...                      NaN
#                     2001-05-29        ...                      NaN
#                     2001-06-06        ...                      NaN
#                     2001-06-14        ...                      NaN
#                     2001-06-22        ...                      NaN
#                     2001-06-30        ...                      NaN
#                     2001-07-08        ...                      NaN
#                     2001-07-16        ...                      NaN
#                     2001-07-24        ...                      NaN
#                     2001-08-01        ...                      NaN
#                     2001-08-09        ...                      NaN
#                     2001-08-17        ...                      NaN
#                     2001-08-25        ...                      NaN
# ...                                   ...                      ...
# 1    30.125  34.875 2011-05-13        ...                      NaN
#                     2011-05-21        ...                      NaN
#                     2011-05-29        ...                      NaN
#                     2011-06-06        ...                      NaN
#                     2011-06-14        ...                      NaN
#                     2011-06-22        ...                      NaN
#                     2011-06-30        ...                      NaN
#                     2011-07-08        ...                      NaN
#                     2011-07-16        ...                      NaN
#                     2011-07-24        ...                      NaN
#                     2011-08-01        ...                      NaN
#                     2011-08-09        ...                      NaN
#                     2011-08-17        ...                      NaN
#                     2011-08-25        ...                      NaN
#                     2011-09-02        ...                      NaN
#                     2011-09-10        ...                      NaN
#                     2011-09-18        ...                      NaN
#                     2011-09-26        ...                      NaN
#                     2011-10-04        ...                      NaN
#                     2011-10-12        ...                      NaN
#                     2011-10-20        ...                      NaN
#                     2011-10-28        ...                      NaN
#                     2011-11-05        ...                      NaN
#                     2011-11-13        ...                      NaN
#                     2011-11-21        ...                      NaN
#                     2011-11-29        ...                      NaN
#                     2011-12-07        ...                      NaN
#                     2011-12-15        ...                      NaN
#                     2011-12-23        ...                      NaN
#                     2011-12-31        ...                      NaN
#
#                                 snow_water_equivalent  soil_moisture  \
# bnds lat    lon     time
# 0    69.875 -19.875 2001-01-05                    NaN            NaN
#                     2001-01-13                    NaN            NaN
#                     2001-01-21                    NaN            NaN
#                     2001-01-29                    NaN            NaN
#                     2001-02-06                    NaN            NaN
#                     2001-02-14                    NaN            NaN
#                     2001-02-22                    NaN            NaN
#                     2001-03-02                    NaN            NaN
#                     2001-03-10                    NaN            NaN
#                     2001-03-18                    NaN            NaN
#                     2001-03-26                    NaN            NaN
#                     2001-04-03                    NaN            NaN
#                     2001-04-11                    NaN            NaN
#                     2001-04-19                    NaN            NaN
#                     2001-04-27                    NaN            NaN
#                     2001-05-05                    NaN            NaN
#                     2001-05-13                    NaN            NaN
#                     2001-05-21                    NaN            NaN
#                     2001-05-29                    NaN            NaN
#                     2001-06-06                    NaN            NaN
#                     2001-06-14                    NaN            NaN
#                     2001-06-22                    NaN            NaN
#                     2001-06-30                    NaN            NaN
#                     2001-07-08                    NaN            NaN
#                     2001-07-16                    NaN            NaN
#                     2001-07-24                    NaN            NaN
#                     2001-08-01                    NaN            NaN
#                     2001-08-09                    NaN            NaN
#                     2001-08-17                    NaN            NaN
#                     2001-08-25                    NaN            NaN
# ...                                               ...            ...
# 1    30.125  34.875 2011-05-13                    NaN      -0.807832
#                     2011-05-21                    NaN      -0.709978
#                     2011-05-29                    NaN      -0.977467
#                     2011-06-06                    NaN      -0.890662
#                     2011-06-14                    NaN      -0.881697
#                     2011-06-22                    NaN      -0.738271
#                     2011-06-30                    NaN      -0.895768
#                     2011-07-08                    NaN      -0.817360
#                     2011-07-16                    NaN            NaN
#                     2011-07-24                    NaN            NaN
#                     2011-08-01                    NaN      -0.977467
#                     2011-08-09                    NaN      -0.977467
#                     2011-08-17                    NaN      -0.830204
#                     2011-08-25                    NaN      -0.790997
#                     2011-09-02                    NaN      -0.750809
#                     2011-09-10                    NaN      -0.603241
#                     2011-09-18                    NaN      -0.632585
#                     2011-09-26                    NaN      -0.424809
#                     2011-10-04                    NaN      -0.496152
#                     2011-10-12                    NaN       1.900601
#                     2011-06-22      -0.542388         NaN           NaN
#                     2011-06-30      -0.547823         NaN           NaN
#                     2011-07-08      -0.551686         NaN           NaN
#                     2011-07-16      -0.554541         NaN           NaN
#                     2011-07-24      -0.556454         NaN           NaN
#                     2011-08-01      -0.557927         NaN           NaN
#                     2011-08-09      -0.559071         NaN           NaN
#                     2011-08-17      -0.559854         NaN           NaN
#                     2011-08-25      -0.560515         NaN           NaN
#                     2011-09-02      -0.560947         NaN           NaN
#                     2011-09-10      -0.561238         NaN           NaN
#                     2011-09-18      -0.561493         NaN           NaN
#                     2011-09-26      -0.343977         NaN           NaN
#                     2011-10-04      -0.499471         NaN           NaN
#                     2011-10-12      -0.554041         NaN           NaN
#                     2011-10-20      -0.560734         NaN           NaN
#                     2011-10-28      -0.561779         NaN           NaN
#                     2011-11-05      -0.561898         NaN           NaN
#                     2011-11-13      -0.561952         NaN           NaN
#                     2011-11-21       0.131757         NaN           NaN
#                     2011-11-29      -0.088530         NaN           NaN
#                     2011-12-07      -0.320738         NaN           NaN
#                     2011-12-15      -0.404257         NaN           NaN
#                     2011-12-23      -0.402541         NaN           NaN
#                     2011-12-31      -0.103562         NaN           NaN
#
#                                 white_sky_albedo
# bnds lat    lon     time
# 0    69.875 -19.875 2001-01-05               NaN
#                     2001-01-13               NaN
#                     2001-01-21               NaN
#                     2001-01-29               NaN
#                     2001-02-06               NaN
#                     2001-02-14               NaN
#                     2001-02-22               NaN
#                     2001-03-02               NaN
#                     2001-03-10               NaN
#                     2001-03-18               NaN
#                     2001-03-26               NaN
#                     2001-04-03               NaN
#                     2001-04-11               NaN
#                     2001-04-19               NaN
#                     2001-04-27               NaN
#                     2001-05-05               NaN
#                     2001-05-13               NaN
#                     2001-05-21               NaN
#                     2001-05-29               NaN
#                     2001-06-06               NaN
#                     2001-06-14               NaN
#                     2001-06-22               NaN
#                     2001-06-30               NaN
#                     2001-07-08               NaN
#                     2001-07-16               NaN
#                     2001-07-24               NaN
#                     2001-08-01               NaN
#                     2001-08-09               NaN
#                     2001-08-17               NaN
#                     2001-08-25               NaN
# ...                                          ...
# 1    30.125  34.875 2011-05-13          0.410770
#                     2011-05-21          0.056216
#                     2011-05-29         -0.313215
#                     2011-06-06         -0.371569
#                     2011-06-14         -0.442566
#                     2011-06-22         -0.545675
#                     2011-06-30         -0.541919
#                     2011-07-08         -0.431216
#                     2011-07-16         -0.358165
#                     2011-07-24         -0.264271
#                     2011-08-01         -0.004284
#                     2011-08-09          0.155856
#                     2011-08-17          0.269316
#                     2011-08-25          0.481155
#                     2011-09-02          0.676957
#                     2011-09-10          0.767711
#                     2011-09-18          0.777596
#                     2011-09-26          1.075246
#                     2011-10-04          1.110798
#                     2011-10-12          0.944465
#                     2011-10-20          0.631900
#                     2011-10-28          0.160909
#                     2011-11-05         -0.038964
#                     2011-11-13         -0.272094
#                     2011-11-21         -0.129488
#                     2011-11-29          0.454034
#                     2011-12-07          0.910527
#                     2011-12-15          1.326224
#                     2011-12-23          1.350996
#                     2011-12-31          1.407380
#
# [35622400 rows x 38 columns]

# %%
sn.boxplot(df[['precipitation','evaporation','soil_moisture','air_temperature_2m','ozone']])
